# %%
import pandas as pd
import numpy as np
import re
import datetime
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer
import xgboost as xgb

pd.set_option('display.max_colwidth',100)

# %%
data = pd.read_csv("../Downloads/ship_data.csv")
data.head(10)
# Out:
#    Passenger ID  Class               Name  Gender   Age  Siblings Count  \
# 0             1      3   Alexander Harris    male  22.0               1
# 1             2      1      Frank Parsons  female  38.0               1
# 2             3      3  Anthony Churchill  female  26.0               0
# 3             4      1   Alexandra Hughes  female  35.0               1
# 4             5      3        Joan Fraser    male  35.0               0
# 5             6      3     Megan Clarkson    male   NaN               0
# 6             7      1        Molly Bower    male  54.0               0
# 7             8      3       Steven Jones    male   2.0               3
# 8             9      3   Bernadette Vance  female  27.0               0
# 9            10      2      Irene Chapman  female -20.0               1
#
#    Parents Count     Fare     Embarked  Survived
# 0              0   7250.0     New York         0
# 1              0  71283.3  Los Angeles         1
# 2              0   7925.0     New York         1
# 3              0  53100.0     New York         1
# 4              0   8050.0     New York         0
# 5              0   8458.3      Chicago         0
# 6              0  51862.5     New York         0
# 7              1  21075.0     New York         0
# 8              2  11133.3     New York         1
# 9              0  30070.8  Los Angeles         1

# %%
data['Gender'].value_counts()
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
data['Class'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Class, dtype: int64

# %%
child = data['Age'] < 16.0
valid_age = data['Age'] > 0.0

# %%
children = data[child & valid_age]
children
# Out:
#      Passenger ID  Class               Name  Gender    Age  Siblings Count  \
# 7               8      3       Steven Jones    male   2.00               3
# 10             11      3        Gavin Payne  female   4.00               1
# 14             15      3        Evan Mackay  female  14.00               0
# 16             17      3         Sonia Knox    male   2.00               4
# 22             23      3      James Russell  female  15.00               0
# 24             25      3       Blake Harris  female   8.00               3
# 39             40      3        Rose Mathis  female  14.00               1
# 43             44      2          Jack Gray  female   3.00               1
# 50             51      3      Trevor Fisher    male   7.00               4
# 58             59      2       Peter Oliver  female   5.00               1
# 59             60      3    Michelle Slater    male  11.00               5
# 63             64      3       Sarah Watson    male   4.00               3
# 78             79      2  Joanne Sutherland    male   0.83               0
# 111           112      3        Nathan Parr  female  14.50               1
# 119           120      3        Jack Powell  female   2.00               4
# 125           126      3       Hannah Smith    male  12.00               1
# 147           148      3      Nathan Gibson  female   9.00               2
# 164           165      3         Wanda Gill    male   1.00               4
# 165           166      3      Rose Mitchell    male   9.00               0
# 171           172      3      Piers Russell    male   4.00               4
# 172           173      3       Megan Fraser  female   1.00               1
# 182           183      3        Irene Terry    male   9.00               4
# 183           184      2    Joshua Lawrence    male   1.00               2
# 184           185      3      Julian McLean  female   4.00               0
# 193           194      2     Dorothy Murray    male   3.00               1
# 205           206      3     Richard Martin  female   2.00               0
# 233           234      3      Sean Campbell  female   5.00               4
# 237           238      2       Diana Hughes  female   8.00               0
# 261           262      3    Warren Springer    male   3.00               4
# 278           279      3       Dan Davidson    male   7.00               4
# ..            ...    ...                ...     ...    ...             ...
# 549           550      2       Dominic Hill    male   8.00               1
# 618           619      2      Blake Roberts  female   4.00               2
# 813              2   31275.0     New York         0
# 819              2   27900.0     New York         0
# 824              1   39687.5     New York         0
# 827              2   37004.2  Los Angeles         1
# 830              0   14454.2  Los Angeles         1
# 831              1   18750.0     New York         1
# 850              2   31275.0     New York         0
# 852              1   15245.8  Los Angeles         0
# 869              1   11133.3     New York         1
# 875              0    7225.0  Los Angeles         1
#
# [82 rows x 10 columns]

# %%
children.shape
# Out:
# (82, 10)

# %%
children['Class'].value_counts()
# Out:
# 3    58
# 2    18
# 1     6
# Name: Class, dtype: int64

# %%
data.isnull().any()
# Out:
# Passenger ID      False
# Class             False
# Name              False
# Gender            False
# Age                True
# Siblings Count    False
# Parents Count     False
# Fare              False
# Embarked           True
# Survived          False
# dtype: bool

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data['Embarked'] = data['Embarked'].fillna("New York")

# %%
data['Embarked'].value_counts()
# Out:
# New York       646
# Los Angeles    168
# Chicago         77
# Name: Embarked, dtype: int64

# %%
data.isnull().any()
# Out:
# Passenger ID      False
# Class             False
# Name              False
# Gender            False
# Age               False
# Siblings Count    False
# Parents Count     False
# Fare              False
# Embarked          False
# Survived          False
# dtype: bool

# %%
data.head()
# Out:
#    Passenger ID  Class               Name  Gender   Age  Siblings Count  \
# 0             1      3   Alexander Harris    male  22.0               1
# 1             2      1      Frank Parsons  female  38.0               1
# 2             3      3  Anthony Churchill  female  26.0               0
# 3             4      1   Alexandra Hughes  female  35.0               1
# 4             5      3        Joan Fraser    male  35.0               0
#
#    Parents Count     Fare     Embarked  Survived
# 0              0   7250.0     New York         0
# 1              0  71283.3  Los Angeles         1
# 2              0   7925.0     New York         1
# 3              0  53100.0     New York         1
# 4              0   8050.0     New York         0

# %%
data['Family'] = data['Siblings Count'] + data['Parents Count']

# %%
data.head()
# Out:
#    Passenger ID  Class               Name  Gender   Age  Siblings Count  \
# 0             1      3   Alexander Harris    male  22.0               1
# 1             2      1      Frank Parsons  female  38.0               1
# 2             3      3  Anthony Churchill  female  26.0               0
# 3             4      1   Alexandra Hughes  female  35.0               1
# 4             5      3        Joan Fraser    male  35.0               0
#
#    Parents Count     Fare     Embarked  Survived  Family
# 0              0   7250.0     New York         0       1
# 1              0  71283.3  Los Angeles         1       1
# 2              0   7925.0     New York         1       0
# 3              0  53100.0     New York         1       1
# 4              0   8050.0     New York         0       0

# %%
alone = data[data['Family'] == 0]
with_family = data[data['Family'] != 0]

# %%
print "alone count:",alone.shape[0]
print "with family count:",with_family.shape[0]
# Out:
# alone count: 537
# with family count: 354

# %%
data.groupby(data['Class']).Survived.value_counts(normalize = True)
# Out:
# Class  Survived
# 1      1           0.629630
#        0           0.370370
# 2      0           0.527174
#        1           0.472826
# 3      0           0.757637
#        1           0.242363
# Name: Survived, dtype: float64

# %%
data.groupby(data['Gender']).Survived.value_counts(normalize = True)
# Out:
# Gender  Survived
# female  1           0.742038
#         0           0.257962
# male    0           0.811092
#         1           0.188908
# Name: Survived, dtype: float64

# %%
data['has_family'] = data['Family']&1
data
# Out:
#      Passenger ID  Class                  Name  Gender        Age  \
"If a person had family survival chance is 48%, whereas if he doesn't have any family 34%"
# Out:
# "If a person had family survival chance is 48%, whereas if he doesn't have any family 34%"

# %% [markdown]
# # 10 th part starts here

# %%
data.head()
# Out:
#    Passenger ID  Class               Name  Gender   Age  Siblings Count  \
# 0             1      3   Alexander Harris    male  22.0               1
# 1             2      1      Frank Parsons  female  38.0               1
# 2             3      3  Anthony Churchill  female  26.0               0
# 3             4      1   Alexandra Hughes  female  35.0               1
# 4             5      3        Joan Fraser    male  35.0               0
#
#    Parents Count     Fare     Embarked  Survived  Family  has_family
# 0              0   7250.0     New York         0       1           1
# 1              0  71283.3  Los Angeles         1       1           1
# 2              0   7925.0     New York         1       0           0
# 3              0  53100.0     New York         1       1           1
# 4              0   8050.0     New York         0       0           0

# %%
data.dtypes
# Out:
# Passenger ID        int64
# Class               int64
# Name               object
# Gender             object
# Age               float64
# Siblings Count      int64
# Parents Count       int64
# Fare              float64
# Embarked           object
# Survived            int64
# Family              int64
# has_family          int64
# dtype: object

# %%
data['Gender'].value_counts()
# Out:
# 0    577
# 1    314
# Name: Gender, dtype: int64

# %%
data.loc[data.Gender == 'male','Gender'] = 0
data.loc[data.Gender == 'female','Gender'] = 1

# %%
data['Embarked'].value_counts()
# Out:
# 0    646
# 1    168
# 2     77
# Name: Embarked, dtype: int64

# %%
data.loc[data.Embarked == 'New York','Embarked'] = 0
data.loc[data.Embarked == 'Los Angeles','Embarked'] = 1
data.loc[data.Embarked == 'Chicago','Embarked'] = 2

# %%
data.head()
# Out:
#    Passenger ID  Class               Name Gender   Age  Siblings Count  \
# 0             1      3   Alexander Harris      0  22.0               1
# 1             2      1      Frank Parsons      1  38.0               1
# 2             3      3  Anthony Churchill      1  26.0               0
# 3             4      1   Alexandra Hughes      1  35.0               1
# 4             5      3        Joan Fraser      0  35.0               0
#
#    Parents Count     Fare Embarked  Survived  Family  has_family
# 0              0   7250.0        0         0       1           1
# 1              0  71283.3        1         1       1           1
# 2              0   7925.0        0         1       0           0
# 3              0  53100.0        0         1       1           1
# 4              0   8050.0        0         0       0           0

# %%
data.isnull().any()
# Out:
# Passenger ID      False
# Class             False
# Name              False
# Gender            False
# Age               False
# Siblings Count    False
# Parents Count     False
# Fare              False
# Embarked          False
# Survived          False
# Family            False
# has_family        False
# dtype: bool

# %%
data.dtypes
# Out:
# Passenger ID        int64
# Class               int64
# Name               object
# Gender             object
# Age               float64
# Siblings Count      int64
# Parents Count       int64
# Fare              float64
# Embarked           object
# Survived            int64
# Family              int64
# has_family          int64
# dtype: object

# %%
data['Gender'] = data['Gender'].convert_objects(convert_numeric=True)
data['Embarked'] = data['Embarked'].convert_objects(convert_numeric=True)
# Out:
# /home/sanju/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# /home/sanju/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app

# %%
features = ['Class','Age','Family','Fare','Embarked','Gender']
target = ['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest=train_test_split(data,test_size=0.10)

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
final_model = XGBClassifier()

# %%
model.fit(Xtrain[features],Xtrain[target])
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
print(model.score(Xtest[features],Xtest[target]))
# Out:
# 0.833333333333

# %%
# training on the whole training data
final_model.fit(data[features],data[target])
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)
